# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data Analyis Datasets/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv')
# # Define the descriptors as a list
descriptors = ['RegionName', 'SizeRank', 'RegionID', 'RegionType', 'StateName']
# # Set the descriptors as the index of the DataFrame
df.set_index(descriptors, inplace=True)
df = df.T

# %%
# df_short = df.loc[:, df.columns[0:6]].pct_change()
df_short = df.loc[:, df.columns[0:6]].apply(lambda x: (x - x.iloc[0]) / x.iloc[0] * 100)
# Plot the time series
ax = df_short.plot(legend=True)

# Set the labels and title
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Plot')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()
# df.columns
